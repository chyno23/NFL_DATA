# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data_new = pd.DataFrame()

for i in range(0, 18):

    url = "https://www.pro-football-reference.com/years/2023/week_"+str(i+1)+".htm"    
    data = pd.read_html(url, encoding='UTF-8')
    
    if len(data) >= 2:  # Verificamos si hay al menos 2 tablas
        data0 = data[0]
        data1 = data[1]
        data_new = pd.concat([data_new, data0, data1])

        for j in range(2, min(32, len(data)), 2):  # Aseguramos que el índice no exceda el tamaño de 'data'
            if j+1 < len(data):  # Verificamos si el índice j+1 es válido
                data_update = pd.concat([data_new, data[j], data[j+1]])
                data_new = data_update

data_new.index = [i % 6 for i in range(len(data_new))]

data1 = pd.DataFrame({

    'Equipo Local':[x for x in data_new[0][1]],
    'Score Local':[x for x in data_new[1][1]],
    'Equipo Visitante':[x for x in data_new[0][2]],
    'Score Visitante':[x for x in data_new[1][2]],
    'Fecha':[x for x in data_new[0][0]],
    'PassYds':[x for x in data_new[1][3]],
    'RushYds':[x for x in data_new[1][4]],
    'RecYds':[x for x in data_new[1][5]],
})
semanas = ['sem' + str(i // 16 + 1) for i in range(len(data1))]
data1['semana'] = semanas
data1
# Out:
#              Equipo Local Score Local       Equipo Visitante Score Visitante  \
# 0           Detroit Lions          21     Kansas City Chiefs              20
# 1       Carolina Panthers          10        Atlanta Falcons              24
# 2      Cincinnati Bengals           3       Cleveland Browns              24
# 3    Jacksonville Jaguars          31     Indianapolis Colts              21
# 4    Tampa Bay Buccaneers          20      Minnesota Vikings              17
# ..                    ...         ...                    ...             ...
# 267        Denver Broncos          14      Las Vegas Raiders              27
# 268    Kansas City Chiefs          13   Los Angeles Chargers              12
# 269      Los Angeles Rams          21    San Francisco 49ers              20
# 270        Dallas Cowboys          38  Washington Commanders              10
# 271         Buffalo Bills          21         Miami Dolphins              14
#
#             Fecha       PassYds         RushYds         RecYds semana
# 0     Sep 7, 2023      Goff-DET  Montgomery-DET   Reynolds-DET   sem1
# 1    Sep 10, 2023     Young-CAR    Allgeier-ATL      Pitts-ATL   sem1
# 2    Sep 10, 2023    Watson-CLE       Chubb-CLE      Moore-CLE   sem1
# 3    Sep 10, 2023  Lawrence-JAX     Etienne-JAX     Ridley-JAX   sem1
# 4    Sep 10, 2023   Cousins-MIN       White-TAM  Jefferson-MIN   sem1
# ..            ...           ...             ...            ...    ...
# 267   Jan 7, 2024   Stidham-DEN       White-LVR    Johnson-DEN  sem17
# 268   Jan 7, 2024     Stick-LAC       Stick-LAC     Parham-LAC  sem17
# 269   Jan 7, 2024   Darnold-SFO       Wentz-LAR     Conley-SFO  sem17
# 270   Jan 7, 2024  Prescott-DAL     Pollard-DAL       Lamb-DAL  sem17
# 271   Jan 7, 2024     Allen-BUF       Allen-BUF     Shakir-BUF  sem17
#
